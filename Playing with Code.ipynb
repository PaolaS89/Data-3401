# %% [markdown]
# ## Playing with what we have Learned:

# %%
1 > 2
# Out:
# False

# %%
# Above is the one of the boolean data types.

# %%
a = 1 > 2 
b = 9 < 0 
a == b
# Out:
# True

# %%
a = b

# %%
# %whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# a                      bool        False
# b                      bool        False
# dataframe_columns      function    <function dataframe_colum<...>ns at 0x00000204203B2E80>
# dataframe_hash         function    <function dataframe_hash at 0x00000204203B2F20>
# dtypes_str             function    <function dtypes_str at 0x00000204203B2C00>
# get_dataframes         function    <function get_dataframes at 0x000002042378C7C0>
# getpass                module      <module 'getpass' from 'C<...>conda3\\Lib\\getpass.py'>
# hashlib                module      <module 'hashlib' from 'C<...>conda3\\Lib\\hashlib.py'>
# import_pandas_safely   function    <function import_pandas_s<...>ly at 0x000002042378CA40>
# is_data_frame          function    <function is_data_frame at 0x00000204203B2FC0>
# json                   module      <module 'json' from 'C:\\<...>\Lib\\json\\__init__.py'>

# %%
c = ( 1, 5, 8, 10) 
print(c)
# Out:
# (1, 5, 8, 10)

# %%
type(c)
# Out:
# tuple

# %%
c.pop(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 c.pop(3)
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
d = 'abcde' 
print(d)
# Out:
# abcde

# %%
d.pop(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 d.pop(3)
#
# AttributeError: 'str' object has no attribute 'pop'

# %%
e = [1, 4, 7, 3]
print(e)
# Out:
# [1, 4, 7, 3]

# %%
type(d)
# Out:
# str

# %%
type(e)
# Out:
# list

# %%
e.pop(3)
# Out:
# 3

# %%
# Can we put tuples, strings, and list, in dictionaries? 
# Not sure since dictionaries keys are immutables and tuples are just completely 
# immutable... ( Not sure)

# %%
my_dict = {}

# %%
type(my_dict)
# Out:
# dict

# %%
my_dict['List of Names'] = [ 'James', 'Max', 'Ivory']
my_dict['Monsters Names'] = [ 'Python', 'Ivo', 'Lex Luthor'] 
my_dict['DoB'] = [ ' 1998', '1899', '2003']

# %%
print(my_dict)
# Out:
# {'List of Names': ['James', 'Max', 'Ivory'], 'Monsters Names': ['Python', 'Ivo', 'Lex Luthor'], 'DoB': [' 1998', '1899', '2003']}

# %%
type(my_dict)
# Out:
# dict

# %%
new_dict = {}
new_dict['Fullmetal Scientist'] = ( 'Maxwell', 'Schrondinger', 'Lovelace')

# %%
print(new_dict)
# Out:
# {'Fullmetal Scientist': ('Maxwell', 'Schrondinger', 'Lovelace')}

# %%
type(new_dict)
# Out:
# dict

# %%
numbers_dict = {}
numbers_dict['Floats'] = [90.6, 99.4, 100.5]

# %%
print(numbers_dict)
# Out:
# {'Floats': [90.6, 99.4, 100.5]}

# %%
boolean_dict = {} 
boolean_dict['Boolean'] = [ 1 == 3, 5 > 4, 0 < 8]

# %%
print(boolean_dict)
# Out:
# {'Boolean': [False, True, True]}

# %%
type(boolean_dict)
# Out:
# dict

# %%
# Let's update the dictionaries. 
my_dict.update(new_dict)

# %%
my_dict + "really cool"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 my_dict + "really cool"
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'str'

# %%
del my_dict

# %%
my_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 my_dict
#
# NameError: name 'my_dict' is not defined

# %%
new_dict
# Out:
# {'Fullmetal Scientist': ('Maxwell', 'Schrondinger', 'Lovelace')}

# %%
new_dict.get('Fullmetal Scientist', 0)
# Out:
# ('Maxwell', 'Schrondinger', 'Lovelace')

# %%
del ['Fullmetal Scientist']
# Out:
#   Cell In[92], line 1
#     del ['Fullmetal Scientist']
#          ^
# SyntaxError: cannot delete literal

# %%
# Let's try to delete the key without the square parenthesis. 
del 'Fullmetal Scientist'
# Out:
#   Cell In[94], line 2
#     del 'Fullmetal Scientist'
#         ^
# SyntaxError: cannot delete literal

# %%
# above didn't work either 
del 'Fullmetal Scientist'.new_dict
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[96], line 2
#       1 # above didn't work either
# ----> 2 del 'Fullmetal Scientist'.new_dict
#
# AttributeError: 'str' object has no attribute 'new_dict'

# %%
del Fullmetal Scientist.new_dict
# Out:
#   Cell In[98], line 1
#     del Fullmetal Scientist.new_dict
#                   ^
# SyntaxError: invalid syntax

# %%
# Above I first need to write the name of the dictionary 
# After that put the [] and put the key inside of it with the 
# quotation marks ( my good friend)

# %%
del new_dict ['Fullmetal Scientist']

# %%
new_dict
# Out:
# {}

# %%
# As you can see above we need to put in the 
# name of the dictionary first and then what key 
# inside the dictionary we want to erase within 
# the square brackets and with ''. 
# This gives us an empty dictionary since it only had one key.

# %%
from IPython.display import Latex

# %%
Latex('$\int_{a}^{b} f(x) dx$')
# Out:
# $\int_{a}^{b} f(x) dx$

# %%
#This is how you write out equations with latex using python. 
# Now to get a value you need to import other sort of things 
# like statistics, scipy, or numpy.

# %%
# %hist
# Out:
# 1 > 2
#
# import json
# import getpass
# import hashlib
#
# def import_pandas_safely():
#     try:
#         return __import__('pandas')
#     except ImportError:
#         return False
#
#
# __pandas = import_pandas_safely()
#
#
# def is_data_frame(v: str):
#     obj = eval(v)
#     if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):
#         return True
#
#
# def dataframe_columns(var):
#     df = eval(var)
#     if isinstance(df, __pandas.core.series.Series):
#         return [[df.name, str(df.dtype)]]
#     return list(map(lambda col: [col, str(df[col].dtype)], df.columns))
#
#
# def dtypes_str(frame):
#     return str(eval(frame).dtypes)
#
# def dataframe_hash(var):
#     # Return a hash including the column names and number of rows
#     df = eval(var)
#     if isinstance(df, __pandas.core.series.Series):
#         return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode('utf-8')).hexdigest()
# ...

# %%
# Let's go over Zip function cause I have yet to understand 
# what the zip function really does.

# %%
#Zip function definition: 
#Zip files are used to compressed more files into simple and a single file.

# %%
# How do we use this zip function:
keys = ['Ten', 'Twenty', 'Thirthy']
values = [10, 20, 30] 
new_dict = dict(zip(keys,values))

# %%
new_dict
# Out:
# {'Ten': 10, 'Twenty': 20, 'Thirthy': 30}

# %%
# We can use the zip funciton to make things 
# into dictionaries if needed be. 
#That is how the zip function works by taking two different 
# files and compressing them into one, which is exactly that definition.

# %%
new_dict.keys()
# Out:
# dict_keys(['Ten', 'Twenty', 'Thirthy'])

# %%
new_dict.keys('Twenty')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 new_dict.keys('Twenty')
#
# TypeError: dict.keys() takes no arguments (1 given)

# %%
# Above does not work therefore there is something that we can do
# different in order to find the values of one keys 
new_dict.keys(Twenty)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Above does not work therefore there is something that we can do
#       2 # different in order to find the values of one keys
# ----> 3 new_dict.keys(Twenty)
#
# NameError: name 'Twenty' is not defined

# %%
# So without the parenthesis the key is not defined 
# If not defined then, why does the other error say takes no arguments. 
# Because the function does not take any sort of arguments inside of it.
