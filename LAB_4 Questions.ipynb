# %% [markdown]
# ## STUDENT NAME: Paola Santos Perez
#
# ## ID NO:1001810057

# %% [markdown]
# ## QUESTION 1 (10 POINTS)
#
# ### Create a line plot for the function 𝑦=2𝑥+3 for 𝑥 values ranging from -10 to 10. Label the x-axis as "X-axis" and the y-axis as "Y-axis". Add a title "Line Plot of y = 2x + 3".

# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %%
x = np.linspace(-10,10)
y = 2*x+3 
plt.plot(x, y) 

plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Line Plot of y = 2x+3")
# Out:
# Text(0.5, 1.0, 'Line Plot of y = 2x+3')

# %% [markdown]
# ## QUESTION 2  (10 POINTS)
#
# ### Plot the function 𝑦 = sin⁡(𝑥) for 𝑥 values ranging from 0 to 2𝜋. Use a red dashed line for the plot. Add grid lines to the plot.

# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %%
x = np.linspace(0, 2*np.pi)
y = np.sin(x)
plt.plot(x,y, color = "red", ls = "--")
plt.grid(True)

# %% [markdown]
# ## QUESTION 3 (20 POINTS)
#
# ### Create a bar plot showing the number of students in different majors. Use the following data: Majors = ['Computer Science', 'Mathematics', 'Physics', 'Chemistry'], Students = [120, 80, 60, 40]. Label the x-axis as "Majors" and the y-axis as "Number of Students".

# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %%
x = ["Computer Science", "Mathematics", "Physics", "Chemistry"]
y = [120, 80, 60, 40]
plt.bar(x,y)
plt.xlabel("Majors")
plt.ylabel("Number of Student")
# Out:
# Text(0, 0.5, 'Number of Student')

# %% [markdown]
# ## QUESTION 4 (10 POINTS)
#
# ### Create a scatter plot with 100 random points. Use a different color and size for each point. Include a color bar to indicate the range of values.

# %%
import numpy as np
import matplotlib 
from matplotlib import pyplot as plt

# %%
x = np.random.rand(100)
y = np.random.rand(100)
colours = np.random.rand(100)
size = np.random.rand(100)
scatter = plt.scatter(x,y, c = colours, s = size)
plt.colorbar(scatter)

# %% [markdown]
# ## QUESTION 5 (20 POINTS)
#
# ### Create a Pandas Series from a dictionary {'a': 10, 'b': 20, 'c': 30, 'd': 40, 'e': 50}. Calculate the sum, mean, and standard deviation of the series.

# %%
from numpy import * 
import pandas as pd
from pandas import *

# %%
d = { "a":10,
      "b":20, 
      "c":30,
      "d":40, 
      "e":50 }
series = pd.Series(d)

# %%
series.mean()
# Out:
# 30.0

# %%
series.sum()
# Out:
# 150

# %%
series.std()
# Out:
# 15.811388300841896

# %% [markdown]
# ## QUESTION 6 (10 POINTS)
#
# ### Create a Pandas Series with values [10, None, 20, None, 30, 40] and default index. Replace the missing values with the mean of the non-missing values.

# %%
import numpy as np
import pandas as pd

# %%
Trike = np.array([10,None,20,None,30,40])
Yi = pd.Series(Trike)
Yi.fillna(Yi.mean())
# Out:
# 0    10.0
# 1    25.0
# 2    20.0
# 3    25.0
# 4    30.0
# 5    40.0
# dtype: float64

# %% [markdown]
# ## QUESTION 7 (20 POINTS)
#
# ### Download a Dataset from https://www.kaggle.com/ choose any dataset from random of your choice. Print the first 10 rows from dataset
#
# ### NOTE : Dont use python code to download dataset. Download the dataset directly from website to your computer and move/upload it to jupyter folder and copy path. Only download direct csv files. If you download zip files make sure you have extracted and copy a csv file to your jupyter folder

# %% [markdown]
# Sample program
# My dataset is a csv file
#
# import pandas as pd
#
# df = pd.read_csv('path_to_extracted_folder/filename.csv')
#
# df.head(10)

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('C:\\Users\\draco\\Downloads\\Data Python 3401\\archive\\dinosaur.csv')
df.head(10)
# Out:
#             Name             Period       Diet        Country
# 0       Aardonyx           Jurassic  herbivore   South Africa
# 1    Abelisaurus  Cretaceous         carnivore  South America
# 2  Abrictosaurus           Jurassic  herbivore   South Africa
# 3     Abrosaurus           Jurassic  herbivore          China
# 4    Abydosaurus         Cretaceous  herbivore  North America
# 5  Acanthopholis         Cretaceous  herbivore        England
# 6  Achelousaurus         Cretaceous  herbivore  North America
# 7   Acheroraptor         Cretaceous  carnivore  North America
# 8  Achillesaurus         Cretaceous  carnivore  South America
# 9   Achillobator         Cretaceous  carnivore       Mongolia

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\draco\\Downloads\\Data Python 3401'
