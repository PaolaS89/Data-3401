# %% [markdown]
# ## STUDENT NAME: Paola Santos Perez
#
# ## ID NO: 1001810057

# %% [markdown]
# ## SECTION-1 (10 POINTS)
#
# ### 1. Create DataFame from the Excel file 'Sample-Superstore.xlsx' & Display First 7 records?.

# %%
import pandas as pd

import numpy as np

# %%
df_sample_superstore = pd.read_excel('C:\\Users\\draco\\Downloads\\Data Python 3401\\Sample-Superstore.xlsx')

# %%
df_sample_superstore.head(7)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# ...

# %% [markdown]
# ### 2. Using Pandas, display the information about the dataframe, including the number of non-null entries, column data types, and memory usage?

# %%
df_sample_superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# ### 3. Count the number of rows and columns in the dataframes and print them?

# %%
df_sample_superstore.shape[0]
# Out:
# 9994

# %%
df_sample_superstore.shape[1]
# Out:
# 21

# %% [markdown]
# ### 4. List all the column names of the dataframe & print them? and Check if there any missing values in the DataFame?

# %%
df_sample_superstore.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df_sample_superstore
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# ### 5. Using Pandas iloc, select rows from rows 5th to the 15th (inclusive) and columns from the 3rd to the 7th(inclusive)?

# %%
df_sample_superstore.iloc[5:16, 3:8]
# Out:
#     Ship Date       Ship Mode Customer ID    Customer Name      Segment
# 5  2014-06-14  Standard Class    BH-11710  Brosina Hoffman     Consumer
# 6  2014-06-14  Standard Class    BH-11710  Brosina Hoffman     Consumer
# 7  2014-06-14  Standard Class    BH-11710  Brosina Hoffman     Consumer
# 8  2014-06-14  Standard Class    BH-11710  Brosina Hoffman     Consumer
# 9  2014-06-14  Standard Class    BH-11710  Brosina Hoffman     Consumer
# 10 2014-06-14  Standard Class    BH-11710  Brosina Hoffman     Consumer
# 11 2014-06-14  Standard Class    BH-11710  Brosina Hoffman     Consumer
# 12 2017-04-20  Standard Class    AA-10480     Andrew Allen     Consumer
# 13 2016-12-10  Standard Class    IM-15070     Irene Maddox     Consumer
# 14 2015-11-26  Standard Class    HP-14815    Harold Pawlan  Home Office
# 15 2015-11-26  Standard Class    HP-14815    Harold Pawlan  Home Office

# %% [markdown]
# ## SECION 2  (10 POINTS)
#
# ### 1. Using Pandas iloc, select the last 5 rows and the 'Order Date', 'Sales' and 'Profit' columns?

# %%
df_sample_superstore.iloc[-5:-1,[2, 17, 20]]
# Out:
#      Order Date  Sales   Profit
# 9989 2014-01-21  0.876   4.1028
# 9990 2017-02-26  0.852  15.6332
# 9991 2017-02-26  0.836  19.3932
# 9992 2017-02-26  0.556  13.3200

# %% [markdown]
# ### 2. Count the number of duplicate rows in Dataframe, and using Pandas, find and display all duplicate rows in the dataframe based on the 'Order ID' column?

# %%
df_sample_superstore[df_sample_superstore["Order ID"].duplicated() == True]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 6          7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 7          8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 8          9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9983    9984  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9985    9986  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9988    9989  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
#
#      Customer ID   Customer Name    Segment        Country             City  \
# 1       CG-12520     CLAIRE GUTE   Consumer  United States        Henderson
# ...

# %% [markdown]
# ### 3. Using Pandas, sort the dataframe by the 'Sales' column in descending order and display the first 5 rows?

# %%
df_sample_superstore["Sales"].sort_index().tail()
# Out:
# 9989    0.876
# 9990    0.852
# 9991    0.836
# 9992    0.556
# 9993    0.444
# Name: Sales, dtype: float64

# %% [markdown]
# ### 4. Using Pandas, sort the dataframe first by 'Region' and then  by 'Profit' in ascending order, and display the first 5 rows?

# %%
df_sample_superstore.sort_values(by = ["Region", "Profit"], ascending = [True, True]).head()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9774    9775  CA-2014-169019 2014-07-26 2014-07-30  Standard Class
# 4991    4992  US-2017-122714 2017-12-07 2017-12-13  Standard Class
# 5310    5311  CA-2017-131254 2017-11-19 2017-11-21     First Class
# 1199    1200  CA-2016-130946 2016-04-08 2016-04-12  Standard Class
# 3324    3325  CA-2014-165309 2014-11-11 2014-11-15  Standard Class
#
#      Customer ID     Customer Name    Segment        Country         City  \
# 9774    LF-17185       Luke Foster   Consumer  United States  San Antonio
# 4991    HG-14965     Henry Goldwyn  Corporate  United States      Chicago
# 5310    NC-18415       Nathan Cano   Consumer  United States      Houston
# 1199    ZC-21910  Zuschuss Carroll   Consumer  United States      Houston
# 3324    KD-16270     Karen Daniels   Consumer  United States      Houston
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### 5. Transform all customer names to uppercase and print first five records ?

# %%
df_sample_superstore["Customer Name"] = df_sample_superstore["Customer Name"].str.upper().head()

# %%
df_sample_superstore.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      CLAIRE GUTE   Consumer  United States        Henderson  ...
# 1      CLAIRE GUTE   Consumer  United States        Henderson  ...
# 2  DARRIN VAN HUFF  Corporate  United States      Los Angeles  ...
# 3   SEAN O'DONNELL   Consumer  United States  Fort Lauderdale  ...
# 4   SEAN O'DONNELL   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### 6. Using Pandas, create a new column 'High Sales' that contains 'Yes' if 'Sales' is greater than 10000, otherwise 'No' & then print first 8 records of 'High Sales' and 'Sales' columns?

# %%
df_sample_superstore["High Sales"] = df_sample_superstore["Sales"].map(lambda x:"Yes" if x > 10000 else "No")

# %%
df_sample_superstore.loc[:, ["High Sales", "Sales"]]
# Out:
#      High Sales      Sales
# 0           Yes  22638.480
# 1           Yes  17499.950
# 2           Yes  13999.960
# 3           Yes  11199.968
# 4           Yes  10499.970
# ...         ...        ...
# 9989         No      0.876
# 9990         No      0.852
# 9991         No      0.836
# 9992         No      0.556
# 9993         No      0.444
#
# [9994 rows x 2 columns]

# %% [markdown]
# ## SECTION 3 (20 POINTS)
#
# ### 1. Determine the average profit for each customer segment and display the results?

# %%
df_sample_superstore.groupby("Segment")["Profit"].mean()
# Out:
# Segment
# Consumer       25.836873
# Corporate      30.456667
# Home Office    33.818664
# Name: Profit, dtype: float64

# %% [markdown]
# ### 2. Display only the rows where the 'Category' is 'Furniture'?

# %%
df_sample_superstore[df_sample_superstore["Category"] == "Furniture"]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 5          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 10        11  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9962    9963  CA-2015-168088 2015-03-19 2015-03-22     First Class
# 9964    9965  CA-2016-146374 2016-12-05 2016-12-10    Second Class
# 9980    9981  US-2015-151435 2015-09-06 2015-09-09    Second Class
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 0       CG-12520       Claire Gute     Consumer  United States
# ...

# %% [markdown]
# ### 3. Caluclate the count of sales for each 'Category'?

# %%
df_sample_superstore.groupby("Category")["Sales"].count()
# Out:
# Category
# Furniture          2121
# Office Supplies    6026
# Technology         1847
# Name: Sales, dtype: int64

# %% [markdown]
# ### 4. Caluclate the sum of sales for each 'Category'?

# %%
df_sample_superstore.groupby("Category")["Sales"].sum()
# Out:
# Category
# Furniture          5.173163e+05
# Office Supplies    1.363310e+06
# Technology         4.165742e+05
# Name: Sales, dtype: float64

# %% [markdown]
# ### 5. Create a new colummn 'Total Cost' which is the product of 'Quantity' and 'Sales'?

# %%
df_sample_superstore["Total Cost"] = df_sample_superstore["Quantity"].multiply(df_sample_superstore["Sales"])

# %%
df_sample_superstore["Total Cost"]
# Out:
# 0       45276.960
# 1       52499.850
# 2       27999.920
# 3       55999.840
# 4       20999.940
#           ...
# 9989        2.628
# 9990        1.704
# 9991        1.672
# 9992        2.224
# 9993        0.888
# Name: Total Cost, Length: 9994, dtype: float64

# %%
df_sample_superstore
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# ### 6. Show only the rows where the 'Region' is 'West' and the 'Discount' is greater than 0.2?

# %%
df_sample_superstore[(df_sample_superstore["Region"] == "West") & (df_sample_superstore["Discount"] > 0.2)]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 95        96  US-2017-109484 2017-11-06 2017-11-12  Standard Class
# 105      106  US-2015-156867 2015-11-13 2015-11-17  Standard Class
# 126      127  US-2017-107272 2017-11-05 2017-11-12  Standard Class
# 201      202  CA-2014-133690 2014-08-03 2014-08-05     First Class
# 296      297  CA-2014-111451 2014-12-26 2014-12-28     First Class
# ...      ...             ...        ...        ...             ...
# 9040    9041  CA-2014-138177 2014-09-19 2014-09-24  Standard Class
# 9128    9129  US-2017-147655 2017-09-04 2017-09-05     First Class
# 9231    9232  CA-2014-148383 2014-12-27 2014-12-31  Standard Class
# 9646    9647  US-2017-107979 2017-06-08 2017-06-13  Standard Class
# 9654    9655  CA-2017-161893 2017-01-23 2017-01-27  Standard Class
#
#      Customer ID   Customer Name      Segment        Country  \
# 95      RB-19705    Roger Barcio  Home Office  United States
# ...

# %% [markdown]
# ### 7. Count the number of order per 'Customer ID'

# %%
df_sample_superstore.groupby("Customer ID")["Order ID"].count()
# Out:
# Customer ID
# AA-10315    11
# AA-10375    15
# AA-10480    12
# AA-10645    18
# AB-10015     6
#             ..
# XP-21865    28
# YC-21895     8
# YS-21880    12
# ZC-21910    31
# ZD-21925     9
# Name: Order ID, Length: 793, dtype: int64

# %% [markdown]
# ### 8. Find the top 5 customers by total profit?

# %%
df_sample_superstore.sort_values(by = ["Profit"], ascending = False).head()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 6826    6827  CA-2016-118689 2016-10-02 2016-10-09  Standard Class
# 8153    8154  CA-2017-140151 2017-03-23 2017-03-25     First Class
# 4190    4191  CA-2017-166709 2017-11-17 2017-11-22  Standard Class
# 9039    9040  CA-2016-117121 2016-12-17 2016-12-21  Standard Class
# 4098    4099  CA-2014-116904 2014-09-23 2014-09-28  Standard Class
#
#      Customer ID  Customer Name    Segment        Country         City  ...  \
# 6826    TC-20980   Tamara Chand  Corporate  United States    Lafayette  ...
# 8153    RB-19360   Raymond Buch   Consumer  United States      Seattle  ...
# 4190    HL-15040   Hunter Lopez   Consumer  United States       Newark  ...
# 9039    AB-10105  Adrian Barton   Consumer  United States      Detroit  ...
# 4098    SC-20095   Sanjit Chand   Consumer  United States  Minneapolis  ...
#
#        Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### 9. Add an new column Order Month that extracts the month from Order Date?

# %%
df_sample_superstore["Order Month"] = df_sample_superstore["Order Date"] = "month"

# %%
df_sample_superstore["Order Month"]
# Out:
# 0       month
# 1       month
# 2       month
# 3       month
# 4       month
#         ...
# 9989    month
# 9990    month
# 9991    month
# 9992    month
# 9993    month
# Name: Order Month, Length: 9994, dtype: object

# %%
df_sample_superstore
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156      month 2016-11-11    Second Class
# 1          2  CA-2016-152156      month 2016-11-11    Second Class
# 2          3  CA-2016-138688      month 2016-06-16    Second Class
# 3          4  US-2015-108966      month 2015-10-18  Standard Class
# 4          5  US-2015-108966      month 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422      month 2014-01-23    Second Class
# 9990    9991  CA-2017-121258      month 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258      month 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258      month 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914      month 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# ### 10. Drop the order Month column from the DataFrame?

# %%
df_sample_superstore.drop( labels = "Order Month", axis = 1)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156      month 2016-11-11    Second Class
# 1          2  CA-2016-152156      month 2016-11-11    Second Class
# 2          3  CA-2016-138688      month 2016-06-16    Second Class
# 3          4  US-2015-108966      month 2015-10-18  Standard Class
# 4          5  US-2015-108966      month 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422      month 2014-01-23    Second Class
# 9990    9991  CA-2017-121258      month 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258      month 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258      month 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914      month 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# ## SECTION 4 (10 POINTS)
#
# ### 1. Rename the Ship Mode column to Shipping Mode?

# %%
df_sample_superstore.rename(columns = {"Ship Mode":"Shipping Mode"})
# Out:
#       Row ID        Order ID Order Date  Ship Date   Shipping Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# ### 2. Filter rows where the Quantity is either 2 or 3?

# %%
df_sample_superstore[(df_sample_superstore['Quantity'] == 2)
                    |(df_sample_superstore["Quantity"] == 3)].head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### 3. Exclude rows where the Region is either 'South' or 'West' and print only 'Region' Column?

# %%
df_sample_superstore2 =df_sample_superstore[(df_sample_superstore["Region"] != "South")
                     &(df_sample_superstore["Region"] != "West")]

# %%
df_sample_superstore2.loc[:,["Region"]]
# Out:
#        Region
# 14    Central
# 15    Central
# 16    Central
# 21    Central
# 22    Central
# ...       ...
# 9981     East
# 9982  Central
# 9983  Central
# 9984     East
# 9985     East
#
# [5171 rows x 1 columns]

# %%
df_sample_superstore2
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 14        15  US-2015-118983 2015-11-22 2015-11-26  Standard Class
# 15        16  US-2015-118983 2015-11-22 2015-11-26  Standard Class
# 16        17  CA-2014-105893 2014-11-11 2014-11-18  Standard Class
# 21        22  CA-2016-137330 2016-12-09 2016-12-13  Standard Class
# 22        23  CA-2016-137330 2016-12-09 2016-12-13  Standard Class
# ...      ...             ...        ...        ...             ...
# 9981    9982  CA-2017-163566 2017-08-03 2017-08-06     First Class
# 9982    9983  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9983    9984  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9984    9985  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985    9986  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
#
#      Customer ID     Customer Name      Segment        Country          City  \
# 14      HP-14815     Harold Pawlan  Home Office  United States    Fort Worth
# ...

# %% [markdown]
# ### 4.Filter  rows where the Product Name is 'Bush Somerset Collection Bookcase' and select the Sales and Profit columns?

# %%
df_Product_B =df_sample_superstore[(df_sample_superstore['Product Name'] == "Bush Somerset Collection Bookcase")]

# %%
df_Product_B.loc[:,["Sales", "Profit"]]
# Out:
#           Sales   Profit
# 0     22638.480  41.9136
# 5399     44.750   6.5490
# 8634      9.984 -89.0664
# 9334      5.880 -15.7176

# %%
df_Product_B
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 5399    5400  CA-2016-117681 2016-04-09 2016-04-14  Standard Class
# 8634    8635  CA-2017-159793 2017-08-25 2017-08-29  Standard Class
# 9334    9335  CA-2017-110198 2017-05-01 2017-05-02     First Class
#
#      Customer ID    Customer Name   Segment        Country           City  \
# 0       CG-12520      Claire Gute  Consumer  United States      Henderson
# 5399    HF-14995  Herbert Flentye  Consumer  United States    Los Angeles
# 8634    SV-20365      Seth Vernon  Consumer  United States   Philadelphia
# 9334    AG-10900    Arthur Gainer  Consumer  United States  Coral Springs
#
#       ... Postal Code  Region       Product ID   Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798  Furniture    Bookcases
# 5399  ...       90004    West  FUR-BO-10001798  Furniture    Bookcases
# ...

# %% [markdown]
# ### 5. Filter  rows where the City is either 'Los Angeles' or 'Henderson' and the Category is either 'Furniture' or 'Office Supplies'?

# %%
df_sample_superstore[(df_sample_superstore["City"] == "Los Angeles") 
                    |(df_sample_superstore["City"] == "Henderson")
                    &(df_sample_superstore["Category"] == "Furniture")
                    |(df_sample_superstore["Category"] == "Office Supplies")]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 5          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9984    9985  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985    9986  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9986    9987  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# ### 6. How many order were placed in each year?

# %%
df_sample_superstore.groupby("Order Date")["Ship Date"].count()
# Out:
# Order Date
# 2014-01-03     1
# 2014-01-04     3
# 2014-01-05     1
# 2014-01-06     9
# 2014-01-07     2
#               ..
# 2017-12-26     4
# 2017-12-27     2
# 2017-12-28    19
# 2017-12-29    12
# 2017-12-30     7
# Name: Ship Date, Length: 1237, dtype: int64

# %%
df_sample_superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df_sample_superstore["year"]=df_sample_superstore["Order Date"].dt.year

# %%
df_sample_superstore.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
df_sample_superstore["year"].value_counts().sort_index()
# Out:
# year
# 2014    1993
# 2015    2102
# 2016    2587
# 2017    3312
# Name: count, dtype: int64
